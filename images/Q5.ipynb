# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/MSC1400_1/AML/HW1/Practical/Q5
# Out:
# /content/drive/MyDrive/MSC1400_1/AML/HW1/Practical/Q5

# %% [markdown]
# Folder containing the project:
# https://drive.google.com/drive/folders/1-GfCQDugaLT4Xrqyk_IkMJC3z3taneNT?usp=sharing

# %% [markdown]
# Test results are reported while training in below parts:
# (number of parameters are also reported while training)

# %% [markdown]
# # Part a

# %%
# !python train.py --epochs 25 --checkpoint_path './checkpoints/' --batch_size 16 --experiment 'a'
# Out:
# Computation device: cuda
#
# 687,401 total parameters.
# 687,401 training parameters.
#
# [INFO]: Training Task Mkhedruli_(Georgian):
# [INFO]: Epoch 1 of 25
# Training
# 100% 37/37 [02:20<00:00,  3.79s/it]
# Validation
# 100% 16/16 [00:54<00:00,  3.40s/it]
# Training loss: 3.782, training acc: 1.871
# Validation loss: 3.707, validation acc: 2.381
#
# Best validation loss: 3.7071304470300674
#
# Saving best model for epoch: 1
#
# --------------------------------------------------
# [INFO]: Epoch 2 of 25
# Training
# 100% 37/37 [00:01<00:00, 21.65it/s]
# Validation
# 100% 16/16 [00:00<00:00, 26.13it/s]
# Training loss: 3.723, training acc: 4.082
# Validation loss: 3.680, validation acc: 2.381
#
# Best validation loss: 3.679588630795479
#
# Saving best model for epoch: 2
#
# --------------------------------------------------
# [INFO]: Epoch 3 of 25
# Training
# 100% 37/37 [00:01<00:00, 21.62it/s]
# Validation
# 100% 16/16 [00:00<00:00, 26.66it/s]
# ...

# %% [markdown]
# # Part b - Scenario 1

# %% [markdown]
# 806,468 total parameters.
# It is printed in the first line.

# %%
# !python train.py --epochs 25 --checkpoint_path './checkpoints/' --batch_size 16 --experiment 'b_1'
# Out:
# Computation device: cuda
#
# 806,468 total parameters.
# 806,468 training parameters.
#
# [INFO]: Epoch 1 of 25
# Training
# 100% 866/866 [00:17<00:00, 49.07it/s]
# Validation
# 100% 379/379 [00:01<00:00, 242.47it/s]
# Task: 0
#  Test Acc: 0.041666666666666664
#  loss: 0.19835357467333475
# Task: 1
#  Test Acc: 0.09770114942528736
#  loss: 0.20661087419794893
# Task: 2
#  Test Acc: 0.0641025641025641
#  loss: 0.20705212690891364
# Task: 3
#  Test Acc: 0.036585365853658534
#  loss: 0.23684040123854228
# Task: 4
#  Test Acc: 0.07083333333333333
#  loss: 0.22608183125654857
# Task: 5
#  Test Acc: 0.041666666666666664
#  loss: 0.19600454635090298
# Task: 6
#  Test Acc: 0.021739130434782608
#  loss: 0.2485509488893592
# Task: 7
#  Test Acc: 0.07142857142857142
#  loss: 0.18886183557056246
# Task: 8
#  Test Acc: 0.038461538461538464
#  loss: 0.21011523405710855
# Task: 9
#  Test Acc: 0.04411764705882353
#  loss: 0.22158404425078748
# Task: 10
#  Test Acc: 0.05555555555555555
# ...

# %% [markdown]
# # Part b - Scenario 2

# %% [markdown]
# 1,760,452 total parameters.

# %%
# !python train.py --epochs 25 --checkpoint_path './checkpoints/' --batch_size 16 --experiment 'b_2'
# Out:
# Computation device: cuda
#
# 1,760,452 total parameters.
# 1,760,452 training parameters.
#
# [INFO]: Epoch 1 of 25
# Training
# 100% 866/866 [00:21<00:00, 40.34it/s]
# Validation
# 100% 379/379 [00:01<00:00, 246.99it/s]
# Task: 0
#  Test Acc: 0.016666666666666666
#  loss: 0.20054372946421306
# Task: 1
#  Test Acc: 0.040229885057471264
#  loss: 0.2133279093380632
# Task: 2
#  Test Acc: 0.04487179487179487
#  loss: 0.20931716301502326
# Task: 3
#  Test Acc: 0.024390243902439025
#  loss: 0.2413511683301228
# Task: 4
#  Test Acc: 0.05
#  loss: 0.22813740074634553
# Task: 5
#  Test Acc: 0.041666666666666664
#  loss: 0.19993695616722107
# Task: 6
#  Test Acc: 0.014492753623188406
#  loss: 0.24989477361457935
# Task: 7
#  Test Acc: 0.03571428571428571
#  loss: 0.18532098474956693
# Task: 8
#  Test Acc: 0.038461538461538464
#  loss: 0.21002840995788574
# Task: 9
#  Test Acc: 0.03431372549019608
#  loss: 0.22497413555781046
# Task: 10
#  Test Acc: 0.03535353535353535
# ...

# %% [markdown]
# As it is shown part a has the best results on test set when training all the models with **same epoch sizes**. Then part b-2 has better results than part b-1.
